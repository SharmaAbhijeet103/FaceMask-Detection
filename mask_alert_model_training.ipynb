# %%
# Configuration related preprocessing step before mounting the drive
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 160690 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.26-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.26-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.26-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
#Mount the google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# Set Directory path for Dataset
os.chdir("/content/drive/My Drive/Projects/Face_mask")
Dataset='dataset'
Data_Dir=os.listdir(Dataset)
print(Data_Dir)
# Out:
# ['with_mask', 'without_mask']

# %%
# Import necessary libraries
import cv2
import numpy as np
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

img_rows, img_cols = 112, 112

images = []
labels = []

for category in Data_Dir:
    folder_path = os.path.join(Dataset, category)
    for img in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img)
        img=cv2.imread(img_path)

        try:
            #Coverting the image into gray scale
            grayscale_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

            #resizing the gray scaled image into size 56x56 in order to keep size of the images consistent           
            resized_img=cv2.resize(grayscale_img,(img_rows, img_cols))
            images.append(resized_img)
            labels.append(category)
        # Exception Handling in case any error occurs
        except Exception as e:
            print('Exception:',e)
        
images=np.array(images)/255.0
images=np.reshape(images,(images.shape[0],img_rows, img_cols,1))


# Perform one hot encoding on the labels since the label are in textual form
lb=LabelBinarizer()
labels=lb.fit_transform(labels)
labels = to_categorical(labels)
labels = np.array(labels)

(train_X, test_X, train_y, test_y) = train_test_split(images, labels, test_size=0.25, 
                                                      random_state=0)

# %%
# Import Necessary Keras Libraries
from keras.models import Sequential
from keras.layers import Dense,Activation,Flatten,Dropout
from keras.layers import Conv2D,MaxPooling2D

# Define model paramters
num_classes = 2
batch_size = 32

# Build CNN model using Sequential API
model=Sequential()

#First layer group containing Convolution, Relu and MaxPooling layers
model.add(Conv2D(64,(3,3),input_shape=(img_rows, img_cols, 1)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

#Second layer group containing Convolution, Relu and MaxPooling layers
model.add(Conv2D(128,(3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

#Flatten and Dropout Layer to stack the output convolutions above as well as cater overfitting
model.add(Flatten())
model.add(Dropout(0.5))

# Softmax Classifier
model.add(Dense(64,activation='relu'))
model.add(Dense(num_classes,activation='softmax'))

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 110, 110, 64)      640
# _________________________________________________________________
# activation (Activation)      (None, 110, 110, 64)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 55, 55, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 53, 53, 128)       73856
# _________________________________________________________________
# activation_1 (Activation)    (None, 53, 53, 128)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 26, 26, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 86528)             0
# _________________________________________________________________
# dropout (Dropout)            (None, 86528)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                5537856
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 130
# =================================================================
# Total params: 5,612,482
# Trainable params: 5,612,482
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Plot the model
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='face_mask_detection_architecture.png')

# %%
## Train the Model

from keras.optimizers import Adam

epochs = 50

model.compile(loss = 'categorical_crossentropy',
              optimizer = Adam(lr=0.001),
              metrics = ['accuracy'])

fitted_model = model.fit(
    train_X,
    train_y,
    epochs = epochs,
    validation_split=0.25)
# Out:
# Epoch 1/50
# 68/68 [==============================] - 35s 37ms/step - loss: 0.7363 - accuracy: 0.5929 - val_loss: 0.5014 - val_accuracy: 0.7455
# Epoch 2/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.4335 - accuracy: 0.8022 - val_loss: 0.3485 - val_accuracy: 0.8456
# Epoch 3/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.3139 - accuracy: 0.8694 - val_loss: 0.3330 - val_accuracy: 0.8428
# Epoch 4/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.2359 - accuracy: 0.8934 - val_loss: 0.3221 - val_accuracy: 0.8623
# Epoch 5/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.1773 - accuracy: 0.9333 - val_loss: 0.2736 - val_accuracy: 0.8832
# Epoch 6/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.1328 - accuracy: 0.9472 - val_loss: 0.2494 - val_accuracy: 0.8999
# Epoch 7/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.1026 - accuracy: 0.9566 - val_loss: 0.2511 - val_accuracy: 0.8985
# Epoch 8/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0862 - accuracy: 0.9688 - val_loss: 0.2547 - val_accuracy: 0.9193
# Epoch 9/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0518 - accuracy: 0.9843 - val_loss: 0.2853 - val_accuracy: 0.9013
# Epoch 10/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0485 - accuracy: 0.9834 - val_loss: 0.2825 - val_accuracy: 0.9040
# Epoch 11/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0241 - accuracy: 0.9952 - val_loss: 0.3635 - val_accuracy: 0.8985
# Epoch 12/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0218 - accuracy: 0.9948 - val_loss: 0.3231 - val_accuracy: 0.8999
# Epoch 13/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0218 - accuracy: 0.9935 - val_loss: 0.3329 - val_accuracy: 0.9110
# Epoch 14/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0240 - accuracy: 0.9941 - val_loss: 0.2883 - val_accuracy: 0.9166
# Epoch 15/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0121 - accuracy: 0.9974 - val_loss: 0.4102 - val_accuracy: 0.8971
# Epoch 16/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0594 - accuracy: 0.9798 - val_loss: 0.3840 - val_accuracy: 0.9096
# Epoch 17/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0194 - accuracy: 0.9938 - val_loss: 0.3433 - val_accuracy: 0.9110
# Epoch 18/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0169 - accuracy: 0.9950 - val_loss: 0.3591 - val_accuracy: 0.9179
# Epoch 19/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.4431 - val_accuracy: 0.9291
# Epoch 20/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0164 - accuracy: 0.9943 - val_loss: 0.3986 - val_accuracy: 0.9110
# Epoch 21/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0245 - accuracy: 0.9924 - val_loss: 0.4668 - val_accuracy: 0.9110
# Epoch 22/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0105 - accuracy: 0.9978 - val_loss: 0.4217 - val_accuracy: 0.9124
# Epoch 23/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0038 - accuracy: 0.9997 - val_loss: 0.3967 - val_accuracy: 0.9179
# Epoch 24/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0032 - accuracy: 0.9996 - val_loss: 0.4920 - val_accuracy: 0.9124
# Epoch 25/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.4254 - val_accuracy: 0.9013
# Epoch 26/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0115 - accuracy: 0.9950 - val_loss: 0.4725 - val_accuracy: 0.8943
# Epoch 27/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0078 - accuracy: 0.9985 - val_loss: 0.4978 - val_accuracy: 0.9026
# Epoch 28/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0229 - accuracy: 0.9917 - val_loss: 0.5011 - val_accuracy: 0.8957
# Epoch 29/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0310 - accuracy: 0.9895 - val_loss: 0.3677 - val_accuracy: 0.9179
# Epoch 30/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.4120 - val_accuracy: 0.9179
# Epoch 31/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.4603 - val_accuracy: 0.9166
# Epoch 32/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0054 - accuracy: 0.9986 - val_loss: 0.4510 - val_accuracy: 0.9166
# Epoch 33/50
# 68/68 [==============================] - 2s 27ms/step - loss: 9.7791e-04 - accuracy: 1.0000 - val_loss: 0.4869 - val_accuracy: 0.9263
# Epoch 34/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0100 - accuracy: 0.9979 - val_loss: 0.4347 - val_accuracy: 0.9124
# Epoch 35/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0074 - accuracy: 0.9974 - val_loss: 0.5220 - val_accuracy: 0.9166
# Epoch 36/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.5599 - val_accuracy: 0.8915
# Epoch 37/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0216 - accuracy: 0.9911 - val_loss: 0.4919 - val_accuracy: 0.9040
# Epoch 38/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0024 - accuracy: 0.9993 - val_loss: 0.5125 - val_accuracy: 0.9166
# Epoch 39/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.5441 - val_accuracy: 0.9110
# Epoch 40/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0161 - accuracy: 0.9939 - val_loss: 0.5235 - val_accuracy: 0.8971
# Epoch 41/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0234 - accuracy: 0.9934 - val_loss: 0.5865 - val_accuracy: 0.8971
# Epoch 42/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0065 - accuracy: 0.9977 - val_loss: 0.6043 - val_accuracy: 0.9026
# Epoch 43/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0133 - accuracy: 0.9960 - val_loss: 0.5071 - val_accuracy: 0.9152
# Epoch 44/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.8258 - val_accuracy: 0.8707
# Epoch 45/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0101 - accuracy: 0.9969 - val_loss: 0.6332 - val_accuracy: 0.9166
# Epoch 46/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.5764 - val_accuracy: 0.9318
# Epoch 47/50
# 68/68 [==============================] - 2s 28ms/step - loss: 0.0023 - accuracy: 0.9995 - val_loss: 0.5305 - val_accuracy: 0.9193
# Epoch 48/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5498 - val_accuracy: 0.9207
# Epoch 49/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0011 - accuracy: 0.9995 - val_loss: 0.6203 - val_accuracy: 0.9207
# Epoch 50/50
# 68/68 [==============================] - 2s 27ms/step - loss: 0.0089 - accuracy: 0.9983 - val_loss: 0.5518 - val_accuracy: 0.9291

# %%
## Plot the Training Loss & Accuracy

from matplotlib import pyplot as plt
# Plot Training and Validation Loss
plt.plot(fitted_model.history['loss'],'r',label='training loss')
plt.plot(fitted_model.history['val_loss'],label='validation loss')
plt.xlabel('Number of Epochs')
plt.ylabel('Loss Value')
plt.legend()
plt.show()

# Plot Training and Validation Accuracy
plt.plot(fitted_model.history['accuracy'],'r',label='training accuracy')
plt.plot(fitted_model.history['val_accuracy'],label='validation accuracy')
plt.xlabel('Number of Epochs')
plt.ylabel('Accuracy Value')
plt.legend()
plt.show()

# %%
# Save or Serialize the model with the name face_mask_detection_alert_system
model.save('face_mask_detection_alert_system.h5')
